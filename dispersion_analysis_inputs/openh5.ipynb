# %%
import h5py

# %%
f = h5py.File("20190122-006.h5", "r")

# %%
list(f.keys())
# Out:
# ['channels', 'config', 'groups']

# %%
channels = f["channels"]
config = f["config"]
groups = f["groups"]

# %%
print(channels.keys())
print(config.keys())
print(groups.keys())
# Out:
# <KeysViewHDF5 ['LC1', 'LC2', 'PT1', 'PT2', 'PT3', 'PT4', 'PT7', 'PT8', 'PT9', 'TC1', 'TC2', 'TC3', 'TC4', 'TC5', 'TC6', 'TC7', 'TC8']>
# <KeysViewHDF5 ['assets.yaml', 'config.yaml']>
# <KeysViewHDF5 []>

# %%
LC1 = channels["LC1"]
LC2 = channels["LC2"]

# %%
print(LC1.keys())
# Out:
# <KeysViewHDF5 ['data', 'time']>

# %%
data_LC1 = LC1["data"]
time_LC1 = LC1["time"]
print(data_LC1)
print(time_LC1)
# Out:
# <HDF5 dataset "data": shape (48513376,), type "<f8">
# <HDF5 dataset "time": shape (48513376,), type "<f8">

# %%
config_yaml = config["config.yaml"]

# %%
print(config_yaml[0])
# Out:
# b'name: CUSF Shadowfax Hybrid Test\n\nnotes:\n\noutputs:\n  - id: CUSF\n    assignments: [\n      PT1, PT2, PT3, PT4, PT7, PT8, PT9,\n      TC1, TC2, TC3, TC4, TC5, TC6, TC7, TC8,\n      LC1, LC2,\n    ]\n    rate: 10000\n\n  - id: GUI\n    assignments: [\n      PT1, PT2, PT3, PT4, PT7, PT8, PT9,\n      TC1, TC2, TC3, TC4, TC5, TC6,\n      LC1, LC2,\n    ]\n    filter: 5\n    rate: 20\n\n  - id: DAQVIEW\n    assignments: [\n      PT1, PT2, PT3, PT4, PT7, PT8, PT9,\n      TC1, TC2, TC3, TC4, TC5, TC6,\n      LC1, LC2,\n    ]\n    filter: 5\n    rate: 20\n\nassignments:\n\n  - role: PT1\n    name: Fill Line\n    xdr: PT1\n    dau: Box1008\n    channel: 1\n    format: "%8.3f"\n\n  - role: PT2\n    name: Flight Tank\n    xdr: PT2\n    dau: Box1008\n    channel: 2\n    format: "%8.3f"\n\n  - role: PT3\n    name: Chamber\n    xdr: PT3\n    dau: Box1008\n    channel: 3\n    format: "%8.3f"\n\n  - role: PT4\n    name: Chamber Trans\n    xdr: PT4\n    dau: Box1008\n    channel: 4\n    format:
# ...

# %%
print(LC1["data"][50:1000]/45e-3*1.5*-9.81)
# Out:
# [5182.41776177 6400.39429329 5791.40602753 5182.41776177 6400.39429329
#  5791.40602753 5182.41776177 5791.40602753 5791.40602753 6400.39429329
#  6400.39429329 6400.39429329 5791.40602753 5791.40602753 6400.39429329
#  5791.40602753 5182.41776177 5791.40602753 5791.40602753 5182.41776177
#  5791.40602753 5182.41776177 5791.40602753 5791.40602753 5791.40602753
#  5182.41776177 6400.39429329 6400.39429329 5791.40602753 5791.40602753
#  5791.40602753 6400.39429329 5182.41776177 5182.41776177 5791.40602753
#  6400.39429329 5791.40602753 6400.39429329 6400.39429329 6400.39429329
#  6400.39429329 5182.41776177 5182.41776177 5791.40602753 5182.41776177
#  5182.41776177 5791.40602753 5791.40602753 5791.40602753 5791.40602753
#  5791.40602753 5791.40602753 5791.40602753 6400.39429329 5791.40602753
#  4573.42949601 5791.40602753 6400.39429329 5182.41776177 5791.40602753
#  5791.40602753 5791.40602753 5182.41776177 6400.39429329 5791.40602753
# ...

# %%
print(LC2["data"][50:1000])
# Out:
# [6.63468391 6.63468391 6.59679741 6.59679741 6.59679741 6.59679741
#  6.55891091 6.55891091 6.59679741 6.59679741 6.63468391 6.59679741
#  6.59679741 6.63468391 6.55891091 6.59679741 6.59679741 6.63468391
#  6.5210244  6.59679741 6.55891091 6.59679741 6.63468391 6.59679741
#  6.55891091 6.59679741 6.55891091 6.55891091 6.59679741 6.55891091
#  6.59679741 6.55891091 6.59679741 6.63468391 6.59679741 6.59679741
#  6.59679741 6.55891091 6.59679741 6.55891091 6.55891091 6.55891091
#  6.55891091 6.59679741 6.55891091 6.59679741 6.5210244  6.5210244
#  6.59679741 6.59679741 6.55891091 6.59679741 6.55891091 6.55891091
#  6.55891091 6.5210244  6.55891091 6.59679741 6.5210244  6.55891091
#  6.55891091 6.55891091 6.55891091 6.5210244  6.55891091 6.59679741
#  6.55891091 6.59679741 6.4831379  6.55891091 6.5210244  6.55891091
#  6.55891091 6.4831379  6.5210244  6.55891091 6.55891091 6.5210244
#  6.55891091 6.5210244  6.5210244  6.5210244  6.4831379  6.55891091
# ...

# %%
Thrust_array = LC1["data"][:]/45e-3*1.5*-9.81
time_array = LC1["time"]

# %%
for i in range(len(thurst_array))

# %%
import pandas as pd

# %%
massSource=pd.read_csv("https://raw.githubusercontent.com/cuspaceflight/CamPyRoS/main/novus_sim_6.1/motor_out.csv")
massSource.head()
massSource.keys()
massSource[["Time", "Solid Fuel Mass (kg)"]]
# Out:
#        Time  Solid Fuel Mass (kg)
# 0      0.01              6.755031
# 1      0.02              6.752289
# 2      0.03              6.749539
# 3      0.04              6.746788
# 4      0.05              6.744037
# ...     ...                   ...
# 2472  24.73              0.558185
# 2473  24.74              0.556779
# 2474  24.75              0.555374
# 2475  24.76              0.553970
# 2476  24.77              0.553970
#
# [2477 rows x 2 columns]
